# %% [markdown]
# # Valores Atípicos
# ### CDMX

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('listings - CDMX.csv')
df
# Out:
#                         id                                       listing_url  \
# 0                    35797                https://www.airbnb.com/rooms/35797
# 1                    44616                https://www.airbnb.com/rooms/44616
# 2                    67703                https://www.airbnb.com/rooms/67703
# 3                    70644                https://www.airbnb.com/rooms/70644
# 4                   107078               https://www.airbnb.com/rooms/107078
# ...                    ...                                               ...
# 26577  1252141718111439700  https://www.airbnb.com/rooms/1252141718111439700
# 26578  1252159821531694005  https://www.airbnb.com/rooms/1252159821531694005
# 26579  1252185591721328995  https://www.airbnb.com/rooms/1252185591721328995
# 26580  1252218347521498445  https://www.airbnb.com/rooms/1252218347521498445
# 26581  1252229157495978163  https://www.airbnb.com/rooms/1252229157495978163
#
# ...

# %%
# Realizamos la selección de las columnas que consideramos relevantes para el análisis
df = df[['id', 'source', 'name', 'description', 'neighborhood_overview',
       'host_id', 'host_name', 'host_since', 'host_location', 'host_about',
       'host_response_time', 'host_response_rate', 'host_acceptance_rate',
       'host_is_superhost', 'host_listings_count', 'host_total_listings_count',
       'host_verifications', 'host_identity_verified',
       'neighbourhood_cleansed', 'latitude', 'longitude', 'property_type',
       'room_type', 'accommodates', 'bathrooms_text', 'bedrooms', 'beds',
       'amenities', 'price', 'minimum_nights', 'maximum_nights',
       'has_availability', 'availability_30', 'availability_60',
       'availability_90', 'availability_365', 'number_of_reviews',
       'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
       'last_review', 'review_scores_rating', 'review_scores_accuracy',
       'review_scores_cleanliness', 'review_scores_checkin',
       'review_scores_communication', 'review_scores_location',
       'review_scores_value', 'instant_bookable', 'reviews_per_month']]
df
# Out:
#                         id           source  \
# 0                    35797      city scrape
# 1                    44616  previous scrape
# 2                    67703      city scrape
# 3                    70644      city scrape
# 4                   107078      city scrape
# ...                    ...              ...
# 26577  1252141718111439700      city scrape
# 26578  1252159821531694005      city scrape
# 26579  1252185591721328995      city scrape
# 26580  1252218347521498445      city scrape
# 26581  1252229157495978163      city scrape
#
#                                                    name  \
# 0                                           Villa Dante
# 1                                          Condesa Haus
# 2                     2 bedroom apt. deco bldg, Condesa
# 3      Beautiful light Studio Coyoacan- full equipped !
# 4                                    NEW  DESIGNER LOFT
# ...                                                 ...
# ...

# %%
# Revisamos si hay valores nulos en el dataset
df.isnull().sum()
# Out:
# id                                 0
# source                             0
# name                               0
# description                      933
# neighborhood_overview          10895
# host_id                            0
# host_name                          0
# host_since                         0
# host_location                   5441
# host_about                     10965
# host_response_time              3622
# host_response_rate              3622
# host_acceptance_rate            2869
# host_is_superhost               1509
# host_listings_count                0
# host_total_listings_count          0
# host_verifications                 0
# host_identity_verified             0
# neighbourhood_cleansed             0
# latitude                           0
# longitude                          0
# property_type                      0
# room_type                          0
# accommodates                       0
# bathrooms_text                    26
# ...

# %% [markdown]
# ### Tratamiento de Valores Nulos

# %%
df1 = df.copy()

# %%
# Rellenamos los valores nulos de la columna 'description' con 'S/D'
df1['description'] = df1['description'].fillna('S/D')

# %%
# Rellenamos los valores nulos de la columna 'neighborhood_overview' con 'S/D'
df1['neighborhood_overview'] = df1['neighborhood_overview'].fillna('S/D')

# %%
# Rellenamos los valores nulos de la columna 'host_about' con 'S/D'
df1['host_location'] = df1['host_location'].fillna('S/D')

# %%
# Rellenamos los valores nulos de la columna 'host_about' con 'S/D'
df1['host_about'] = df1['host_about'].fillna('S/D')

# %%
# Rellenamos los valores nulos de la columna 'host_response_time' con 'S/D'
df1['host_response_time'] = df1['host_response_time'].fillna('S/D')

# %%
# Rellenamos los valores nulos de la columna 'host_response_rate' con 'S/D'
df1['host_response_rate'] = df1['host_response_rate'].fillna('S/D')

# %%
# Rellenamos los valores nulos de la columna 'host_acceptance_rate' con 'S/D'
df1['host_acceptance_rate'] = df1['host_acceptance_rate'].fillna('S/D')

# %%
# Rellenamos los valores nulos de la columna 'host_is_superhost' con 'f' (valor booleano)
df1['host_is_superhost'] = df1['host_is_superhost'].fillna("f")

# %%
# Rellenamos los valores nulos de la columna 'bathrooms_text' con '1 bath'
df1['bathrooms_text'] = df1['bathrooms_text'].fillna('1 bath')

# %%
# Rellenamos los valores nulos de la columna 'bedrooms' con '1'
df1['bedrooms'] = df1['bedrooms'].fillna(1)

# %%
# Rellenamos los valores nulos de la columna 'beds' con '1'
df1['beds'] = df1['beds'].fillna(1)

# %%
# Para la columna price, primero convertimos los valores a numéricos y después interpolamos los valores nulos
df1['price'] = df1['price'].str.replace('$', '')
df1['price'] = df1['price'].str.replace(',', '')
df1['price'] = pd.to_numeric(df1['price'])
df1['price'] = df1['price'].interpolate()

# %%
# Rellenamos los valores nulos de la columna 'has_availability' con 'f' (valor booleano)
df1['has_availability'] = df1['has_availability'].fillna('f')

# %%
# Rellenamos las columnas 'first_review' y 'last_review' con 'S/D'
df1['first_review'] = df1['first_review'].fillna('S/D')
df1['last_review'] = df1['last_review'].fillna('S/D')

# %%
# Rellenamos los valores nulos de las columnas de review_scores_... con 0
df1['review_scores_rating'] = df1['review_scores_rating'].fillna(0)
df1['review_scores_accuracy'] = df1['review_scores_accuracy'].fillna(0)
df1['review_scores_cleanliness'] = df1['review_scores_cleanliness'].fillna(0)
df1['review_scores_checkin'] = df1['review_scores_checkin'].fillna(0)
df1['review_scores_communication'] = df1['review_scores_communication'].fillna(0)
df1['review_scores_location'] = df1['review_scores_location'].fillna(0)
df1['review_scores_value'] = df1['review_scores_value'].fillna(0)

# %%
# Rellenamos los valores nulos de la columna 'reviews_per_month' con la interpolación de los valores
df1['reviews_per_month'] = df1['reviews_per_month'].interpolate()
# Quitamos el único valor nulo restante
df1 = df1.dropna()

# %%
# Realizamos la comprobación de que no hay valores nulos en el dataset
df1.isnull().sum()
# Out:
# id                             0
# source                         0
# name                           0
# description                    0
# neighborhood_overview          0
# host_id                        0
# host_name                      0
# host_since                     0
# host_location                  0
# host_about                     0
# host_response_time             0
# host_response_rate             0
# host_acceptance_rate           0
# host_is_superhost              0
# host_listings_count            0
# host_total_listings_count      0
# host_verifications             0
# host_identity_verified         0
# neighbourhood_cleansed         0
# latitude                       0
# longitude                      0
# property_type                  0
# room_type                      0
# accommodates                   0
# bathrooms_text                 0
# bedrooms                       0
# beds                           0
# amenities                      0
# ...

# %% [markdown]
# ### Tratamiento de Valores Atípicos

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26581 entries, 1 to 26581
# Data columns (total 50 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           26581 non-null  int64
#  1   source                       26581 non-null  object
#  2   name                         26581 non-null  object
#  3   description                  26581 non-null  object
#  4   neighborhood_overview        26581 non-null  object
#  5   host_id                      26581 non-null  int64
#  6   host_name                    26581 non-null  object
#  7   host_since                   26581 non-null  object
#  8   host_location                26581 non-null  object
#  9   host_about                   26581 non-null  object
#  10  host_response_time           26581 non-null  object
#  11  host_response_rate           26581 non-null  object
#  12  host_acceptance_rate         26581 non-null  object
# ...

# %%
# separamos las variables cualitativas y cuantitativas
cualitativas = df1.select_dtypes(include=['object'])
cuantitativas = df1.select_dtypes(include=['float64', 'int64'])

# %%
# El dataset cuenta con las variables 'id' y 'host_id' que no son relevantes para el análisis
# por lo que las movemos al principio del dataset junto con las variables cualitativas
cualitativas = pd.concat([df1['id'], df1['host_id'], cualitativas], axis=1)
cuantitativas = cuantitativas.drop(['id', 'host_id', 'latitude', 'longitude'], axis=1)

# %%
cualitativas.columns
# Out:
# Index(['id', 'host_id', 'source', 'name', 'description',
#        'neighborhood_overview', 'host_name', 'host_since', 'host_location',
#        'host_about', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_verifications',
#        'host_identity_verified', 'neighbourhood_cleansed', 'property_type',
#        'room_type', 'bathrooms_text', 'amenities', 'has_availability',
#        'first_review', 'last_review', 'instant_bookable'],
#       dtype='object')

# %%
cuantitativas.columns
# Out:
# Index(['host_listings_count', 'host_total_listings_count', 'accommodates',
#        'bedrooms', 'beds', 'price', 'minimum_nights', 'maximum_nights',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'number_of_reviews', 'number_of_reviews_ltm',
#        'number_of_reviews_l30d', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'reviews_per_month'],
#       dtype='object')

# %%
# Realizamos un diagrama de cajas para las variables cuantitativas
fig = plt.figure(figsize=(30, 30))
cuantitativas.plot(kind='box', vert=False)
plt.title('Valores Atípicos de las Variables Cuantitativas')
plt.show()

# %%
# realizamos el diagrama de caja de cada columna de forma individual
for column in cuantitativas.columns:
    plt.figure(figsize=(10, 3))
    cuantitativas.boxplot(column=column, vert=False)
    plt.title(f'Valores Atípicos de la Variable: {column}')
    plt.show()

# %% [markdown]
# ### Método "Desviación Estandar" Para Detectar Valores Atípicos

# %%
# Método aplicando la desviación estándar para encontrar los valores extremos
# Se considera que un valor es extremo si está a más de 3 desviaciones estándar de la media
y=cuantitativas
Limite_Superior=y.mean() + 3*y.std()
Limite_Inferior=y.mean() - 3*y.std()
print("------------- Limite Superior -------------- \n", Limite_Superior)
print("------------- Limite Inferior ------------- \n", Limite_Inferior)
# Out:
# ------------- Limite Superior --------------
#  host_listings_count              329.562936
# host_total_listings_count        614.899247
# accommodates                      10.430244
# bedrooms                           5.339493
# beds                               6.956480
# price                          16992.174782
# minimum_nights                    81.831616
# maximum_nights                  1793.894158
# availability_30                   48.523116
# availability_60                   97.330138
# availability_90                  149.605333
# availability_365                 602.602106
# number_of_reviews                271.157962
# number_of_reviews_ltm             75.060921
# number_of_reviews_l30d             6.824093
# review_scores_rating               9.123843
# review_scores_accuracy             9.183237
# review_scores_cleanliness          9.129470
# review_scores_checkin              9.256468
# review_scores_communication        9.251695
# ...

# %%
# obtenemos los datos y los outliers se convierten en NaN
df2 = cuantitativas[(y <= Limite_Superior) & (y >= Limite_Inferior)]
df2
# Out:
#        host_listings_count  host_total_listings_count  accommodates  bedrooms  \
# 1                     12.0                       13.0           NaN       5.0
# 2                      3.0                        4.0           4.0       2.0
# 3                      3.0                        4.0           2.0       1.0
# 4                      5.0                        7.0           2.0       1.0
# 5                      3.0                        4.0           2.0       2.0
# ...                    ...                        ...           ...       ...
# 26577                167.0                      279.0           4.0       2.0
# 26578                 16.0                       16.0           2.0       1.0
# 26579                 16.0                       16.0           2.0       1.0
# 26580                 16.0                       16.0           2.0       1.0
# 26581                  4.0                        6.0           2.0       1.0
#
# ...

# %%
# corroboramos valores nulos
df2.isnull().sum()
# Out:
# host_listings_count            304
# host_total_listings_count      380
# accommodates                   526
# bedrooms                       286
# beds                           466
# price                           94
# minimum_nights                 190
# maximum_nights                   1
# availability_30                  0
# availability_60                  0
# availability_90                  0
# availability_365                 0
# number_of_reviews              608
# number_of_reviews_ltm          432
# number_of_reviews_l30d         511
# review_scores_rating             0
# review_scores_accuracy           0
# review_scores_cleanliness        0
# review_scores_checkin            0
# review_scores_communication      0
# review_scores_location           0
# review_scores_value              0
# reviews_per_month              387
# dtype: int64

# %%
# realizamos una copia del dataframe y remplazamos valores nulos por la media
df_clean = df2.copy()
df_clean.fillna(round(df2.mean(), 1), inplace=True)
df_clean.isnull().sum()
# Out:
# host_listings_count            0
# host_total_listings_count      0
# accommodates                   0
# bedrooms                       0
# beds                           0
# price                          0
# minimum_nights                 0
# maximum_nights                 0
# availability_30                0
# availability_60                0
# availability_90                0
# availability_365               0
# number_of_reviews              0
# number_of_reviews_ltm          0
# number_of_reviews_l30d         0
# review_scores_rating           0
# review_scores_accuracy         0
# review_scores_cleanliness      0
# review_scores_checkin          0
# review_scores_communication    0
# review_scores_location         0
# review_scores_value            0
# reviews_per_month              0
# dtype: int64

# %%
# realizamos el diagrama de caja
fig = plt.figure(figsize=(30, 30))
df_clean.plot(kind='box', vert=False)
plt.title('Valores Atípicos de las Variables Cuantitativas')
plt.show()

# %% [markdown]
# Método "Cuantiles" para Detectar Valores Atípicos

# %%
# método aplicando rango intercuartílico para detectar outliers. Encuentro cuartiles 0.25 y 0.75

y = cuantitativas

percentil25 = y.quantile(0.25) # Q1
percentil75 = y.quantile(0.75) # Q3
IQR = percentil75 - percentil25

Limite_Superior_IQR = percentil75 + 1.5 * IQR
Limite_Inferior_IQR = percentil25 - 1.5 * IQR

print("------------ Limite Superior -------------  \n", Limite_Superior_IQR)
print("------------ Limite Inferior -------------  \n", Limite_Inferior_IQR)
# Out:
# ------------ Limite Superior -------------
#  host_listings_count              33.500
# host_total_listings_count        39.500
# accommodates                      7.000
# bedrooms                          3.500
# beds                              3.500
# price                          2964.750
# minimum_nights                    3.500
# maximum_nights                 2542.500
# availability_30                  63.500
# availability_60                 113.000
# availability_90                 162.500
# availability_365                710.500
# number_of_reviews               135.500
# number_of_reviews_ltm            52.500
# number_of_reviews_l30d            5.000
# review_scores_rating              5.525
# review_scores_accuracy            5.485
# review_scores_cleanliness         5.580
# review_scores_checkin             5.450
# review_scores_communication       5.495
# review_scores_location            5.480
# review_scores_value               5.500
# ...

# %%
# obtenemos los datos y los outliers se convierten en NaN
df3 = cuantitativas[(y <= Limite_Superior_IQR) & (y >= Limite_Inferior_IQR)]
df3.isnull().sum()
# Out:
# host_listings_count            3567
# host_total_listings_count      3764
# accommodates                   1352
# bedrooms                        858
# beds                           2447
# price                          2039
# minimum_nights                 3584
# maximum_nights                    0
# availability_30                   0
# availability_60                   0
# availability_90                   0
# availability_365                  0
# number_of_reviews              2328
# number_of_reviews_ltm          1318
# number_of_reviews_l30d          813
# review_scores_rating           4161
# review_scores_accuracy         4517
# review_scores_cleanliness      4157
# review_scores_checkin          4374
# review_scores_communication    4466
# review_scores_location         4248
# review_scores_value            4228
# reviews_per_month              1004
# dtype: int64

# %%
# realizamos una copia del dataframe y remplazamos valores atípicos por la media
df_IQR = df3.copy()
df_IQR.fillna(round(df3.mean(), 1), inplace=True)
df_IQR
# Out:
#        host_listings_count  host_total_listings_count  accommodates  bedrooms  \
# 1                     12.0                       13.0           2.9       1.4
# 2                      3.0                        4.0           4.0       2.0
# 3                      3.0                        4.0           2.0       1.0
# 4                      5.0                        7.0           2.0       1.0
# 5                      3.0                        4.0           2.0       2.0
# ...                    ...                        ...           ...       ...
# 26577                  6.2                        7.3           4.0       2.0
# 26578                 16.0                       16.0           2.0       1.0
# 26579                 16.0                       16.0           2.0       1.0
# 26580                 16.0                       16.0           2.0       1.0
# 26581                  4.0                        6.0           2.0       1.0
#
# ...

# %%
fig = plt.figure(figsize=(30, 30))
df_IQR.plot(kind='box', vert=False)
plt.title('Valores Atípicos de las Variables Cuantitativas')
plt.show()

# %%
# unimos las variables cualitativas con las cuantitativas
dataset_limpio = pd.concat([cualitativas, df_IQR], axis=1)
dataset_limpio.isnull().sum()
# Out:
# id                             0
# host_id                        0
# source                         0
# name                           0
# description                    0
# neighborhood_overview          0
# host_name                      0
# host_since                     0
# host_location                  0
# host_about                     0
# host_response_time             0
# host_response_rate             0
# host_acceptance_rate           0
# host_is_superhost              0
# host_verifications             0
# host_identity_verified         0
# neighbourhood_cleansed         0
# property_type                  0
# room_type                      0
# bathrooms_text                 0
# amenities                      0
# has_availability               0
# first_review                   0
# last_review                    0
# instant_bookable               0
# host_listings_count            0
# host_total_listings_count      0
# accommodates                   0
# ...

# %%
dataset_limpio.to_csv('listings_CDMX_limpio.csv')
